# %%
# Dependencies and Setup
# !pip install citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import re
from pprint import pprint
from sqlalchemy import create_engine

# %%
csv_file = "../Resources/branded_food.csv"
branded_food_df = pd.read_csv(csv_file)
branded_food_df.head()
# Out:
# C:\Users\17062\anaconda\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    fdc_id        brand_owner     gtin_upc  \
# 0  356425  G. T. Japan, Inc.  1.90221e+10
# 1  356426       FRESH & EASY     5.05e+12
# 2  356427       FRESH & EASY     5.05e+12
# 3  356428       FRESH & EASY     5.05e+12
# 4  356429       FRESH & EASY     5.05e+12
#
#                                          ingredients  serving_size  \
# 0  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...          40.0
# 1  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...          37.0
# 2  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...          34.0
# 3  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...          35.0
# 4  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...          37.0
#
#   serving_size_unit household_serving_fulltext  \
# 0                 g                    1 PIECE
# 1                 g                     2 Tbsp
# 2                 g                     2 Tbsp
# 3                 g                     2 Tbsp
# 4                 g                     2 Tbsp
#
#                   branded_food_category data_source modified_date  \
# 0             Ice Cream & Frozen Yogurt          LI    11/15/2017
# 1  Ketchup, Mustard, BBQ & Cheese Sauce          LI     4/26/2018
# 2  Ketchup, Mustard, BBQ & Cheese Sauce          LI     4/26/2018
# 3  Ketchup, Mustard, BBQ & Cheese Sauce          LI     4/26/2018
# 4  Ketchup, Mustard, BBQ & Cheese Sauce          LI     4/26/2018
#
#   available_date
# 0     11/15/2017
# 1      4/26/2018
# 2      4/26/2018
# 3      4/26/2018
# 4      4/26/2018

# %%
clean_branded_food_df = branded_food_df[['fdc_id', 'brand_owner', 'ingredients', 'branded_food_category']].copy()
clean_branded_food_df.head()
# Out:
#    fdc_id        brand_owner  \
# 0  356425  G. T. Japan, Inc.
# 1  356426       FRESH & EASY
# 2  356427       FRESH & EASY
# 3  356428       FRESH & EASY
# 4  356429       FRESH & EASY
#
#                                          ingredients  \
# 0  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...
# 1  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...
# 2  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...
# 3  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...
# 4  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...
#
#                   branded_food_category
# 0             Ice Cream & Frozen Yogurt
# 1  Ketchup, Mustard, BBQ & Cheese Sauce
# 2  Ketchup, Mustard, BBQ & Cheese Sauce
# 3  Ketchup, Mustard, BBQ & Cheese Sauce
# 4  Ketchup, Mustard, BBQ & Cheese Sauce

# %%
clean_branded_food_df_500 = clean_branded_food_df.head(500)

# %%
clean_branded_food_df_500.head(20)
# Out:
#     fdc_id                 brand_owner  \
# 0   356425           G. T. Japan, Inc.
# 1   356426                FRESH & EASY
# 2   356427                FRESH & EASY
# 3   356428                FRESH & EASY
# 4   356429                FRESH & EASY
# 5   356430                FRESH & EASY
# 6   356431                FRESH & EASY
# 7   356432                FRESH & EASY
# 8   356433                FRESH & EASY
# 9   356434                FRESH & EASY
# 10  356435                FRESH & EASY
# 11  356436                FRESH & EASY
# 12  356437                FRESH & EASY
# 13  356438                FRESH & EASY
# 14  356439                FRESH & EASY
# 15  356440                FRESH & EASY
# 16  356441                FRESH & EASY
# 17  356442                FRESH & EASY
# 18  356443                FRESH & EASY
# 19  356444  McConnell's Ice Cream Inc.
#
#                                           ingredients  \
# 0   ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...
# 1   WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...
# 2   SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...
# 3   TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...
# 4   SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...
# 5   SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...
# 6   SUGAR, DISTILLED VINEGAR, WATER, TOMATO PUREE ...
# 7   WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...
# 8   TOMATO PUREE, ONION PUREE, SUGAR, MOLASSES, DI...
# 9   ORGANIC GRAIN VINEGAR, WATER, ORGANIC MUSTARD ...
# 10  DISTILLED VINEGAR, WATER, HONEY, MUSTARD FLOUR...
# 11  DISTILLED VINEGAR, WATER, MUSTARD SEED, SALT, ...
# 12  ORGANIC DISTILLED VINEGAR, WATER, ORGANIC MUST...
# 13  DISTILLED VINEGAR, WATER, MUSTARD SEED, SALT, ...
# 14  DISTILLED VINEGAR, WATER, MUSTARD SEED, SALT, ...
# 15  DISTILLED VINEGAR, WATER, MUSTARD SEED, SALT, ...
# 16  ORGANIC TOMATO CONCENTRATE (WATER, ORGANIC TOM...
# 17  WATER, SOYBEAN OIL, EGGS, DISTILLED VINEGAR, F...
# 18  SOYBEAN OIL, EGGS, CIDER VINEGAR, WATER, CONTA...
# 19  CREAM, MILK, CANE SUGAR, NON FAT MILK SOLIDS, ...
#
#                    branded_food_category
# 0              Ice Cream & Frozen Yogurt
# 1   Ketchup, Mustard, BBQ & Cheese Sauce
# 2   Ketchup, Mustard, BBQ & Cheese Sauce
# 3   Ketchup, Mustard, BBQ & Cheese Sauce
# 4   Ketchup, Mustard, BBQ & Cheese Sauce
# 5   Ketchup, Mustard, BBQ & Cheese Sauce
# 6   Ketchup, Mustard, BBQ & Cheese Sauce
# 7   Ketchup, Mustard, BBQ & Cheese Sauce
# 8   Ketchup, Mustard, BBQ & Cheese Sauce
# 9   Ketchup, Mustard, BBQ & Cheese Sauce
# 10  Ketchup, Mustard, BBQ & Cheese Sauce
# 11  Ketchup, Mustard, BBQ & Cheese Sauce
# 12  Ketchup, Mustard, BBQ & Cheese Sauce
# 13  Ketchup, Mustard, BBQ & Cheese Sauce
# 14  Ketchup, Mustard, BBQ & Cheese Sauce
# 15  Ketchup, Mustard, BBQ & Cheese Sauce
# 16  Ketchup, Mustard, BBQ & Cheese Sauce
# 17           Salad Dressing & Mayonnaise
# 18           Salad Dressing & Mayonnaise
# 19             Ice Cream & Frozen Yogurt

# %%
# create list for ingredients

ingred_df = clean_branded_food_df_500[["fdc_id","ingredients"]]
ingred_df.head()
# Out:
#    fdc_id                                        ingredients
# 0  356425  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...
# 1  356426  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...
# 2  356427  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...
# 3  356428  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...
# 4  356429  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...

# %%
ingred_df_ingredients =ingred_df["ingredients"]

# %%
ingred_df_ingredients.dtype
# Out:
# dtype('O')

# %%
ingred_df_ingredients.str.split()
# Out:
# 0      [ICE, CREAM, INGREDIENTS:, MILK,, CREAM,, SUGA...
# 1      [WATER,, SUGAR,, TOMATO, PASTE,, MOLASSES,, DI...
# 2      [SUGAR,, WATER,, DISTILLED, VINEGAR,, TOMATO, ...
# 3      [TOMATO, PUREE, (WATER,, TOMATO, PASTE),, SUGA...
# 4      [SUGAR,, DISTILLED, VINEGAR,, WATER,, TOMATO, ...
# 5      [SUGAR,, DISTILLED, VINEGAR,, WATER,, TOMATO, ...
# 6      [SUGAR,, DISTILLED, VINEGAR,, WATER,, TOMATO, ...
# 7      [WATER,, SUGAR,, TOMATO, PASTE,, MOLASSES,, DI...
# 8      [TOMATO, PUREE,, ONION, PUREE,, SUGAR,, MOLASS...
# 9      [ORGANIC, GRAIN, VINEGAR,, WATER,, ORGANIC, MU...
# 10     [DISTILLED, VINEGAR,, WATER,, HONEY,, MUSTARD,...
# 11     [DISTILLED, VINEGAR,, WATER,, MUSTARD, SEED,, ...
# 12     [ORGANIC, DISTILLED, VINEGAR,, WATER,, ORGANIC...
# 13     [DISTILLED, VINEGAR,, WATER,, MUSTARD, SEED,, ...
# 14     [DISTILLED, VINEGAR,, WATER,, MUSTARD, SEED,, ...
# 15     [DISTILLED, VINEGAR,, WATER,, MUSTARD, SEED,, ...
# 16     [ORGANIC, TOMATO, CONCENTRATE, (WATER,, ORGANI...
# 17     [WATER,, SOYBEAN, OIL,, EGGS,, DISTILLED, VINE...
# 18     [SOYBEAN, OIL,, EGGS,, CIDER, VINEGAR,, WATER,...
# 19     [CREAM,, MILK,, CANE, SUGAR,, NON, FAT, MILK, ...
# 20                                 [SUGAR,, CORNSTARCH.]
# 21                                              [SUGAR.]
# 22     [SEMOLINA, (WHEAT),, DURUM, FLOUR, (WHEAT),, N...
# 23     [PREPARED, DARK, RED, KIDNEY, BEANS,, WATER,, ...
# 24     [EXTRA, VIRGIN, OLIVE, OIL**,, SOY, LECITHIN,,...
# 25     [TURKEY, BREAST,, WATER,, DEXTROSE,, CONTAINS,...
# 26     [PORK, CURED, WITH, WATER,, HONEY,, CONTAINS, ...
# 27     [PORK, CURED, WITH:, WATER,, DEXTROSE,, CONTAI...
# 28     [BEEF,, WATER,, CONTAINS, LESS, THAN, 2%, SODI...
# 29     [PASTEURIZED, MILK,, CHEESE, CULTURE,, SALT,, ...
#                              ...
# 470    [ORGANIC, YELLOW, CORN,, EXPELLER, PRESSED, CA...
# 471    [STONE, GROUND, CORN,, HIGH, OLEIC, SUNFLOWER,...
# 472    [STONE, GROUND, YELLOW, CORN,, STONE, GROUND, ...
# 473    [ORGANIC, GARBANZO, BEANS, (GARBANZO, BEANS,, ...
# 474                  [ORGANIC, APPLE,, ORGANIC, BANANA.]
# 475    [DARK, CHOCOLATE, (SUGAR,, CHOCOLATE, LIQUOR,,...
# 476    [RAW, ORGANIC, CASHEW, BUTTER,, RAW, ORGANIC, ...
# 477    [RAW, ORGANIC, CASHEW, BUTTER,, RAW, ORGANIC, ...
# 478    [TEA, WITH, TEA, EXTRACT,, HIBISCUS,, NATURAL,...
# 479            [ORGANIC, DURUM, WHOLE, WHEAT, SEMOLINA.]
# 480       [MALTODEXTRIN,, BLENDED, GREEN, TEA, POWDERS.]
# 481    [ORGANIC, FENNEL,, ORGANIC, CELERY, ROOT,, ORG...
# 482    [HIBISCUS,, ROSEHIPS,, ORANGE, PEEL,, NATURAL,...
# 483    [SPROUTED, ORGANIC, WHOLE, WHEAT, BERRIES,, OR...
# 484    [ORGANIC, UNBLEACHED, WHEAT, FLOUR,, WATER,, O...
# 485    [CINNAMON, ROLL, (WATER,, TAPIOCA, STARCH,, BR...
# 486    [ORGANIC, PASTEURIZED, CULTURED, WHOLE, AND, S...
# 487    [ORGANIC, PASTEURIZED, CULTURED, MILK,, SALT,,...
# 488    [ORGANIC, BROWN, RICE,, ORGANIC, BLACK, BEANS,...
# 489    [ORGANIC, BLACK, BEANS,, PRESERVATIVE-FREE, TO...
# 490    [BROWN, SUGAR,, GLUTEN, FREE, OATS,, PREMIUM, ...
# 491    [POTATO, STARCH,, SORGHUM, FLOUR,, TAPIOCA, FL...
# 492    [GLUTEN, FREE, FLOUR, (BROWN, RICE,, SWEET, RI...
# 493                     [ORGANIC, ROASTED, BROWN, RICE.]
# 494                               [ORGANIC, WHITE, RICE]
# 495                                      [ORGANIC, RICE]
# 496    [ORGANIC,, PASTEURIZED, CULTURED, MILK, &, CRE...
# 497    [ORGANIC,, PASTEURIZED, CULTURED, MILK, &, CRE...
# 498    [PASTEURIZED, AND, CULTURED, ORGANIC, SOYMILK,...
# 499    [NATURALLY, BREWED, SOY, SAUCE, (WATER,, WHEAT...
# Name: ingredients, Length: 500, dtype: object

# %%
print(type(ingred_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#Drop null values
ingred_df.dropna()
ingred_df.count()
# Out:
# fdc_id         500
# ingredients    500
# dtype: int64

# %%
# use itertuples to scan dataframe for regex pattern ORGANIC
organic_count = 0
search_word = re.compile("\W*(ORGANIC)\W*")
ingredient_count = 0
counter=0
organic_list = []
# for each row in the dataframe
# itertuples will return each row as row.header_title
ingredient_count2 = []
organic_count2 = []
for row in ingred_df.itertuples():
    #print(row)
    ingredient_count = len(row.ingredients.split(",")) #ingredients is a bunch of strings, convert to list and count
    organic_list = re.findall(search_word,row.ingredients)
    organic_count = len(organic_list)
    #print(ingred_df.head())
    key = row.fdc_id
    ingredient_count2.append(ingredient_count)
    organic_count2.append(organic_count)

    counter += 1
    
ingred_df["ingredient_count"] = ingredient_count2
ingred_df["organic_count"] = organic_count2

# %%
ingred_df.head(20)
# Out:
#     fdc_id                                        ingredients  \
# 0   356425  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...
# 1   356426  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...
# 2   356427  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...
# 3   356428  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...
# 4   356429  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...
# 5   356430  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...
# 6   356431  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PUREE ...
# 7   356432  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...
# 8   356433  TOMATO PUREE, ONION PUREE, SUGAR, MOLASSES, DI...
# 9   356434  ORGANIC GRAIN VINEGAR, WATER, ORGANIC MUSTARD ...
# 10  356435  DISTILLED VINEGAR, WATER, HONEY, MUSTARD FLOUR...
# 11  356436  DISTILLED VINEGAR, WATER, MUSTARD SEED, SALT, ...
# 12  356437  ORGANIC DISTILLED VINEGAR, WATER, ORGANIC MUST...
# 13  356438  DISTILLED VINEGAR, WATER, MUSTARD SEED, SALT, ...
# 14  356439  DISTILLED VINEGAR, WATER, MUSTARD SEED, SALT, ...
# 15  356440  DISTILLED VINEGAR, WATER, MUSTARD SEED, SALT, ...
# 16  356441  ORGANIC TOMATO CONCENTRATE (WATER, ORGANIC TOM...
# 17  356442  WATER, SOYBEAN OIL, EGGS, DISTILLED VINEGAR, F...
# 18  356443  SOYBEAN OIL, EGGS, CIDER VINEGAR, WATER, CONTA...
# 19  356444  CREAM, MILK, CANE SUGAR, NON FAT MILK SOLIDS, ...
#
#     ingredient_count  organic_count
# 0                 21              0
# 1                 13              0
# 2                 15              0
# 3                 16              0
# 4                 15              0
# 5                 14              0
# 6                 15              0
# 7                 15              0
# 8                 31              0
# 9                  7              5
# 10                 7              0
# 11                 8              0
# 12                 6              4
# 13                 8              0
# 14                 7              0
# 15                 7              0
# 16                 7              6
# 17                10              0
# 18                 8              0
# 19                13              1

# %%
csv_file = "../Resources/food.csv"
food_df = pd.read_csv(csv_file)
food_df.head()
# Out:
#    fdc_id     data_type                 description  food_category_id  \
# 0  356425  branded_food     MOCHI ICE CREAM BONBONS               NaN
# 1  356426  branded_food     CHIPOTLE BARBECUE SAUCE               NaN
# 2  356427  branded_food  HOT & SPICY BARBECUE SAUCE               NaN
# 3  356428  branded_food              BARBECUE SAUCE               NaN
# 4  356429  branded_food              BARBECUE SAUCE               NaN
#
#   publication_date
# 0       2019-04-01
# 1       2019-04-01
# 2       2019-04-01
# 3       2019-04-01
# 4       2019-04-01

# %%
#Re-organize the food dataframe to include only what we need
clean_food_df = food_df[['fdc_id', 'description']].copy()
clean_food_df.head()
# Out:
#    fdc_id                 description
# 0  356425     MOCHI ICE CREAM BONBONS
# 1  356426     CHIPOTLE BARBECUE SAUCE
# 2  356427  HOT & SPICY BARBECUE SAUCE
# 3  356428              BARBECUE SAUCE
# 4  356429              BARBECUE SAUCE

# %%
clean_branded_food_df.head()
# Out:
#    fdc_id        brand_owner  \
# 0  356425  G. T. Japan, Inc.
# 1  356426       FRESH & EASY
# 2  356427       FRESH & EASY
# 3  356428       FRESH & EASY
# 4  356429       FRESH & EASY
#
#                                          ingredients  \
# 0  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...
# 1  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...
# 2  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...
# 3  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...
# 4  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...
#
#                   branded_food_category
# 0             Ice Cream & Frozen Yogurt
# 1  Ketchup, Mustard, BBQ & Cheese Sauce
# 2  Ketchup, Mustard, BBQ & Cheese Sauce
# 3  Ketchup, Mustard, BBQ & Cheese Sauce
# 4  Ketchup, Mustard, BBQ & Cheese Sauce

# %%
#Set index to id
indexed_df = clean_branded_food_df.set_index('fdc_id')
indexed_df.head()
# Out:
#               brand_owner                                        ingredients  \
# fdc_id
# 356425  G. T. Japan, Inc.  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...
# 356426       FRESH & EASY  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...
# 356427       FRESH & EASY  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...
# 356428       FRESH & EASY  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...
# 356429       FRESH & EASY  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...
#
#                        branded_food_category
# fdc_id
# 356425             Ice Cream & Frozen Yogurt
# 356426  Ketchup, Mustard, BBQ & Cheese Sauce
# 356427  Ketchup, Mustard, BBQ & Cheese Sauce
# 356428  Ketchup, Mustard, BBQ & Cheese Sauce
# 356429  Ketchup, Mustard, BBQ & Cheese Sauce

# %%
#Split the many ingredients in ingredients column into separate columns
ingredients_split = indexed_df['ingredients'].str.split(', ', -1, expand=True)
ingredients_split.head()
# Out:
#                                 0                  1                  2    \
# fdc_id
# 356425  ICE CREAM INGREDIENTS: MILK              CREAM              SUGAR
# 356426                        WATER              SUGAR       TOMATO PASTE
# 356427                        SUGAR              WATER  DISTILLED VINEGAR
# 356428          TOMATO PUREE (WATER      TOMATO PASTE)              SUGAR
# 356429                        SUGAR  DISTILLED VINEGAR              WATER
#
#                                3                  4    \
# fdc_id
# 356425  STRAWBERRIES (STRAWBERRIES             SUGAR)
# 356426                    MOLASSES  DISTILLED VINEGAR
# 356427                TOMATO PASTE           MOLASSES
# 356428           DISTILLED VINEGAR           MOLASSES
# 356429                TOMATO PASTE              HONEY
#
#                                         5                     6    \
# fdc_id
# 356425                    CORN SYRUP SOLIDS             SKIM MILK
# 356426  CONTAINS 2% OR LESS OF: CORN STARCH                  SALT
# 356427                 MODIFIED CORN STARCH                  SALT
# 356428                                WATER  MODIFIED CORN STARCH
# 356429                             MOLASSES  MODIFIED CORN STARCH
#
#                                 7                                         8    \
# fdc_id
# 356425                         WHEY                            NATURAL FLAVOR
# 356426        DRIED CHIPOTLE PEPPER                      NATURAL SMOKE FLAVOR
# 356427  PINEAPPLE JUICE CONCENTRATE  CONTAINS 1% OR LESS OF: JALAPENO PEPPERS
# 356428                         SALT                           BOURBON WHISKEY
# 356429                         SALT    CONTAINS 1% OR LESS OF: NATURAL FLAVOR
#
#                                           9    ...   163   164   165   166  \
# fdc_id                                         ...
# 356425                               GUAR GUM  ...  None  None  None  None
# 356426                          MUSTARD FLOUR  ...  None  None  None  None
# 356427                                  SPICE  ...  None  None  None  None
# 356428  CONTAINS 1% OR LESS OF: MUSTARD FLOUR  ...  None  None  None  None
# 356429            PINEAPPLE JUICE CONCENTRATE  ...  None  None  None  None
#
#          167   168   169   170   171   172
# fdc_id
# 356425  None  None  None  None  None  None
# 356426  None  None  None  None  None  None
# 356427  None  None  None  None  None  None
# 356428  None  None  None  None  None  None
# 356429  None  None  None  None  None  None
#
# [5 rows x 173 columns]

# %%
#Merge two dataframes together
ingredients_df = pd.merge(indexed_df, ingredients_split, on='fdc_id', how='inner')
ingredients_df.head()
# Out:
#               brand_owner                                        ingredients  \
# fdc_id
# 356425  G. T. Japan, Inc.  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...
# 356426       FRESH & EASY  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...
# 356427       FRESH & EASY  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...
# 356428       FRESH & EASY  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...
# 356429       FRESH & EASY  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...
#
#                        branded_food_category                            0  \
# fdc_id
# 356425             Ice Cream & Frozen Yogurt  ICE CREAM INGREDIENTS: MILK
# 356426  Ketchup, Mustard, BBQ & Cheese Sauce                        WATER
# 356427  Ketchup, Mustard, BBQ & Cheese Sauce                        SUGAR
# 356428  Ketchup, Mustard, BBQ & Cheese Sauce          TOMATO PUREE (WATER
# 356429  Ketchup, Mustard, BBQ & Cheese Sauce                        SUGAR
#
#                         1                  2                           3  \
# fdc_id
# 356425              CREAM              SUGAR  STRAWBERRIES (STRAWBERRIES
# 356426              SUGAR       TOMATO PASTE                    MOLASSES
# 356427              WATER  DISTILLED VINEGAR                TOMATO PASTE
# 356428      TOMATO PASTE)              SUGAR           DISTILLED VINEGAR
# 356429  DISTILLED VINEGAR              WATER                TOMATO PASTE
#
#                         4                                    5  \
# fdc_id
# 356425             SUGAR)                    CORN SYRUP SOLIDS
# 356426  DISTILLED VINEGAR  CONTAINS 2% OR LESS OF: CORN STARCH
# 356427           MOLASSES                 MODIFIED CORN STARCH
# 356428           MOLASSES                                WATER
# 356429              HONEY                             MOLASSES
#
#                            6  ...   163   164   165   166   167   168   169  \
# fdc_id                        ...
# 356425             SKIM MILK  ...  None  None  None  None  None  None  None
# 356426                  SALT  ...  None  None  None  None  None  None  None
# 356427                  SALT  ...  None  None  None  None  None  None  None
# 356428  MODIFIED CORN STARCH  ...  None  None  None  None  None  None  None
# 356429  MODIFIED CORN STARCH  ...  None  None  None  None  None  None  None
#
#          170   171   172
# fdc_id
# 356425  None  None  None
# 356426  None  None  None
# 356427  None  None  None
# 356428  None  None  None
# 356429  None  None  None
#
# [5 rows x 176 columns]

# %%
#Drop original ingredients column
ingredients_df = ingredients_df.drop(labels = ['ingredients'], axis=1)
ingredients_df.head()
# Out:
#               brand_owner                 branded_food_category  \
# fdc_id
# 356425  G. T. Japan, Inc.             Ice Cream & Frozen Yogurt
# 356426       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 356427       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 356428       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 356429       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
#
#                                   0                  1                  2  \
# fdc_id
# 356425  ICE CREAM INGREDIENTS: MILK              CREAM              SUGAR
# 356426                        WATER              SUGAR       TOMATO PASTE
# 356427                        SUGAR              WATER  DISTILLED VINEGAR
# 356428          TOMATO PUREE (WATER      TOMATO PASTE)              SUGAR
# 356429                        SUGAR  DISTILLED VINEGAR              WATER
#
#                                  3                  4  \
# fdc_id
# 356425  STRAWBERRIES (STRAWBERRIES             SUGAR)
# 356426                    MOLASSES  DISTILLED VINEGAR
# 356427                TOMATO PASTE           MOLASSES
# 356428           DISTILLED VINEGAR           MOLASSES
# 356429                TOMATO PASTE              HONEY
#
#                                           5                     6  \
# fdc_id
# 356425                    CORN SYRUP SOLIDS             SKIM MILK
# 356426  CONTAINS 2% OR LESS OF: CORN STARCH                  SALT
# 356427                 MODIFIED CORN STARCH                  SALT
# 356428                                WATER  MODIFIED CORN STARCH
# 356429                             MOLASSES  MODIFIED CORN STARCH
#
#                                   7  ...   163   164   165   166   167   168  \
# fdc_id                               ...
# 356425                         WHEY  ...  None  None  None  None  None  None
# 356426        DRIED CHIPOTLE PEPPER  ...  None  None  None  None  None  None
# 356427  PINEAPPLE JUICE CONCENTRATE  ...  None  None  None  None  None  None
# 356428                         SALT  ...  None  None  None  None  None  None
# 356429                         SALT  ...  None  None  None  None  None  None
#
#          169   170   171   172
# fdc_id
# 356425  None  None  None  None
# 356426  None  None  None  None
# 356427  None  None  None  None
# 356428  None  None  None  None
# 356429  None  None  None  None
#
# [5 rows x 175 columns]

# %%
#Reset index to make id a column again
ingredients_df = ingredients_df.reset_index()
ingredients_df.head()
# Out:
#    fdc_id        brand_owner                 branded_food_category  \
# 0  356425  G. T. Japan, Inc.             Ice Cream & Frozen Yogurt
# 1  356426       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 2  356427       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 3  356428       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 4  356429       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
#
#                              0                  1                  2  \
# 0  ICE CREAM INGREDIENTS: MILK              CREAM              SUGAR
# 1                        WATER              SUGAR       TOMATO PASTE
# 2                        SUGAR              WATER  DISTILLED VINEGAR
# 3          TOMATO PUREE (WATER      TOMATO PASTE)              SUGAR
# 4                        SUGAR  DISTILLED VINEGAR              WATER
#
#                             3                  4  \
# 0  STRAWBERRIES (STRAWBERRIES             SUGAR)
# 1                    MOLASSES  DISTILLED VINEGAR
# 2                TOMATO PASTE           MOLASSES
# 3           DISTILLED VINEGAR           MOLASSES
# 4                TOMATO PASTE              HONEY
#
#                                      5                     6  ...   163   164  \
# 0                    CORN SYRUP SOLIDS             SKIM MILK  ...  None  None
# 1  CONTAINS 2% OR LESS OF: CORN STARCH                  SALT  ...  None  None
# 2                 MODIFIED CORN STARCH                  SALT  ...  None  None
# 3                                WATER  MODIFIED CORN STARCH  ...  None  None
# 4                             MOLASSES  MODIFIED CORN STARCH  ...  None  None
#
#     165   166   167   168   169   170   171   172
# 0  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None
#
# [5 rows x 176 columns]

# %%
separated_ingredient_df = pd.melt(ingredients_df, id_vars = ['fdc_id', 'brand_owner', 'branded_food_category'], value_name = 'ingredient')
separated_ingredient_df.head(25)
# Out:
#     fdc_id                 brand_owner                 branded_food_category  \
# 0   356425           G. T. Japan, Inc.             Ice Cream & Frozen Yogurt
# 1   356426                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 2   356427                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 3   356428                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 4   356429                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 5   356430                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 6   356431                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 7   356432                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 8   356433                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 9   356434                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 10  356435                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 11  356436                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 12  356437                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 13  356438                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 14  356439                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 15  356440                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 16  356441                FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 17  356442                FRESH & EASY           Salad Dressing & Mayonnaise
# 18  356443                FRESH & EASY           Salad Dressing & Mayonnaise
# 19  356444  McConnell's Ice Cream Inc.             Ice Cream & Frozen Yogurt
# 20  356445   Stater Bros. Markets Inc.    Granulated, Brown & Powdered Sugar
# 21  356446   Stater Bros. Markets Inc.    Granulated, Brown & Powdered Sugar
# 22  356447   Stater Bros. Markets Inc.                 Pasta by Shape & Type
# 23  356448   Stater Bros. Markets Inc.                Canned & Bottled Beans
# 24  356449                Meijer, Inc.              Vegetable & Cooking Oils
#
#    variable                         ingredient
# 0         0        ICE CREAM INGREDIENTS: MILK
# 1         0                              WATER
# 2         0                              SUGAR
# 3         0                TOMATO PUREE (WATER
# 4         0                              SUGAR
# 5         0                              SUGAR
# 6         0                              SUGAR
# 7         0                              WATER
# 8         0                       TOMATO PUREE
# 9         0              ORGANIC GRAIN VINEGAR
# 10        0                  DISTILLED VINEGAR
# 11        0                  DISTILLED VINEGAR
# 12        0          ORGANIC DISTILLED VINEGAR
# 13        0                  DISTILLED VINEGAR
# 14        0                  DISTILLED VINEGAR
# 15        0                  DISTILLED VINEGAR
# 16        0  ORGANIC TOMATO CONCENTRATE (WATER
# 17        0                              WATER
# 18        0                        SOYBEAN OIL
# 19        0                              CREAM
# 20        0                              SUGAR
# 21        0                             SUGAR.
# 22        0                   SEMOLINA (WHEAT)
# 23        0     PREPARED DARK RED KIDNEY BEANS
# 24        0           EXTRA VIRGIN OLIVE OIL**

# %%
#Drop un-necessary column
separated_ingredient_df = separated_ingredient_df.drop(labels = ['variable'], axis=1)
separated_ingredient_df.head()
# Out:
#    fdc_id        brand_owner                 branded_food_category  \
# 0  356425  G. T. Japan, Inc.             Ice Cream & Frozen Yogurt
# 1  356426       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 2  356427       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 3  356428       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
# 4  356429       FRESH & EASY  Ketchup, Mustard, BBQ & Cheese Sauce
#
#                     ingredient
# 0  ICE CREAM INGREDIENTS: MILK
# 1                        WATER
# 2                        SUGAR
# 3          TOMATO PUREE (WATER
# 4                        SUGAR

# %%
# Check the data
separated_ingredient_df.count()
# Out:
# fdc_id                   45044010
# brand_owner              44901631
# branded_food_category    43293596
# ingredient                3880097
# dtype: int64

# %%
# Drop null values
separated_ingredient_df = separated_ingredient_df.dropna()
separated_ingredient_df.count()
# Out:
# fdc_id                   3693889
# brand_owner              3693889
# branded_food_category    3693889
# ingredient               3693889
# dtype: int64

# %%
#Merge two dataframes into one on 'fdc_id'
#DATASETS ARE MERGED BEFORE INSERTING INTO DB
combined_df = pd.merge(separated_ingredient_df, clean_food_df, on="fdc_id")
combined_df.head()
# Out:
#    fdc_id        brand_owner      branded_food_category  \
# 0  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 1  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 2  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 3  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 4  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
#
#                     ingredient              description
# 0  ICE CREAM INGREDIENTS: MILK  MOCHI ICE CREAM BONBONS
# 1                        CREAM  MOCHI ICE CREAM BONBONS
# 2                        SUGAR  MOCHI ICE CREAM BONBONS
# 3   STRAWBERRIES (STRAWBERRIES  MOCHI ICE CREAM BONBONS
# 4                       SUGAR)  MOCHI ICE CREAM BONBONS

# %%
#Check count of rows
combined_df.count()
# Out:
# fdc_id                   3693889
# brand_owner              3693889
# branded_food_category    3693889
# ingredient               3693889
# description              3693889
# dtype: int64

# %%
#Connect to local database
database_path = "organic_food_db.sqlite"
engine = create_engine(f'sqlite:///{database_path}')

# %%
#Check for tables
engine.table_names()
# Out:
# []

# %%
#Use pandas to load csv converted dataframe into database
combined_df.to_sql(name='tbl_combined_food', con=engine, if_exists='append', index=False)
ingred_df.to_sql(name='tbl_organic_count', con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['tbl_combined_food', 'tbl_organic_count']

# %%
#Confirm data has been added by querying the table
pd.read_sql_query('select * from tbl_combined_food', con=engine).head()
# Out:
#    fdc_id        brand_owner      branded_food_category  \
# 0  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 1  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 2  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 3  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 4  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
#
#                     ingredient              description
# 0  ICE CREAM INGREDIENTS: MILK  MOCHI ICE CREAM BONBONS
# 1                        CREAM  MOCHI ICE CREAM BONBONS
# 2                        SUGAR  MOCHI ICE CREAM BONBONS
# 3   STRAWBERRIES (STRAWBERRIES  MOCHI ICE CREAM BONBONS
# 4                       SUGAR)  MOCHI ICE CREAM BONBONS

# %%
pd.read_sql_query('select * from tbl_organic_count', con=engine).head()
# Out:
#    fdc_id                                        ingredients  \
# 0  356425  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...
# 1  356426  WATER, SUGAR, TOMATO PASTE, MOLASSES, DISTILLE...
# 2  356427  SUGAR, WATER, DISTILLED VINEGAR, TOMATO PASTE,...
# 3  356428  TOMATO PUREE (WATER, TOMATO PASTE), SUGAR, DIS...
# 4  356429  SUGAR, DISTILLED VINEGAR, WATER, TOMATO PASTE,...
#
#    ingredient_count  organic_count
# 0                21              0
# 1                13              0
# 2                15              0
# 3                16              0
# 4                15              0

# %%
#SECOND JOIN/MERGE OF DATASETS
pd.read_sql_query('select * from tbl_combined_food a join tbl_organic_count b on a.fdc_id = b.fdc_id', con=engine).head()
# Out:
#    fdc_id        brand_owner      branded_food_category  \
# 0  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 1  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 2  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 3  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
# 4  356425  G. T. Japan, Inc.  Ice Cream & Frozen Yogurt
#
#                     ingredient              description  fdc_id  \
# 0  ICE CREAM INGREDIENTS: MILK  MOCHI ICE CREAM BONBONS  356425
# 1                        CREAM  MOCHI ICE CREAM BONBONS  356425
# 2                        SUGAR  MOCHI ICE CREAM BONBONS  356425
# 3   STRAWBERRIES (STRAWBERRIES  MOCHI ICE CREAM BONBONS  356425
# 4                       SUGAR)  MOCHI ICE CREAM BONBONS  356425
#
#                                          ingredients  ingredient_count  \
# 0  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...                21
# 1  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...                21
# 2  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...                21
# 3  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...                21
# 4  ICE CREAM INGREDIENTS: MILK, CREAM, SUGAR, STR...                21
#
#    organic_count
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
pd.read_sql_query('select fdc_id, ingredient_count from tbl_organic_count where organic_count>0', con=engine).head()
# Out:
#    fdc_id  ingredient_count
# 0  356434                 7
# 1  356437                 6
# 2  356441                 7
# 3  356444                13
# 4  356468                12
